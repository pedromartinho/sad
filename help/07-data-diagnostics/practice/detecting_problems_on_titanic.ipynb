# %%
import pandas as pd 
import numpy as np 
% matplotlib inline
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('../data/titanic_exercise.csv')
data.head(n=20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex    Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male   22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# ...

# %%
data['Age'].plot.hist()

# %%
age_right = data[(data['Age']>=1) & (data['Age']<100)]
age_right.sort_values(by='Age', ascending=True) 
age_right.head(n=10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
age_right['Age'].plot.hist()

# %%
age_right['Sex'].unique()
# Out:
# array(['male', 'female', 'Squirrel'], dtype=object)

# %%
sex_right = age_right[age_right['Sex']!='Squirrl']
sex_right.head(n=10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
sex_right['Survived'].unique()
# Out:
# array([  0,   1, 700])

# %%
survived_right = sex_right[sex_right['Survived']!=700]
survived_right.head(n=10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
survived_right['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
survived_right['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5])

# %%
survived_right['Parch'].unique()

# %%
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
survived_right['Fare'].plot.hist()

# %%
no_duplicades = survived_right[survived_right.duplicated() == False]

# %%
no_nan = no_duplicades.drop('Cabin', axis=1)

# %%
clean_ages = no_nan.dropna()

# %% [markdown]
# # I believe everything is clean now!!!
