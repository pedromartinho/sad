# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
data = pd.read_csv("../data/misterous_data.csv")
plt.style.use('seaborn-dark-palette')

# %%
data[data['category']==1].plot.scatter(x='x',y='y',title='EPIC!')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data[data['category']==2].plot.scatter(x='x',y='y',title='IT IS ME!')

# %%
data.boxplot(column=["x","y"], by="category");
