# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
algae = pd.read_csv("data/algae.csv")
students = pd.read_csv("data/students.csv")
plt.style.use('seaborn-dark-palette')

# %%
print (algae.shape)
print (algae.dtypes)
algae.head(5)
# Out:
# (200, 11)
# season              object
# river_size          object
# fluid_velocity      object
# pH                 float64
# Oxygen             float64
# Chloride           float64
# Nitrates           float64
# Ammonium           float64
# Orthophosphate     float64
# Phosphate          float64
# Chlorophyll        float64
# dtype: object
#    season river_size fluid_velocity     pH  Oxygen  Chloride  Nitrates  \
# 0  winter      small          medium  8.00     9.8     60.80      6.24
# 1  spring      small          medium  8.35     8.0     57.75      1.29
# 2  autumn      small          medium  8.10    11.4     40.02      5.33
# 3  spring      small          medium  8.07     4.8     77.36      2.30
# 4  autumn      small          medium  8.06     9.0     55.35     10.42
#
#    Ammonium  Orthophosphate  Phosphate  Chlorophyll
# 0    578.00          105.00     170.00         50.0
# 1    370.00          428.75     558.75          1.3
# 2    346.67          125.67     187.06         15.6
# 3     98.18           61.18     138.70          1.4
# 4    233.70           58.22      97.58         10.5

# %%
print (students.shape)
print (students.dtypes)
students.head(5)
# Out:
# (48, 13)
# Sex            object
# Major          object
# Major2         object
# Major3         object
# Level          object
# Brothers        int64
# Sisters         int64
# BirthOrder    float64
# MilesHome     float64
# MilesLocal    float64
# Sleep         float64
# BloodType      object
# Height        float64
# dtype: object
#       Sex              Major            Major2   Major3      Level  Brothers  \
# 0  female  actuarial science               NaN      NaN   freshman         0
# 1    male         statistics  computer science      NaN     junior         3
# 2    male         statistics          japanese  spanish   freshman         0
# 3    male        mathematics        statistics      NaN     senior         0
# 4    male         statistics               NaN      NaN  sophomore         0
#
#    Sisters  BirthOrder  MilesHome  MilesLocal  Sleep BloodType  Height
# 0        1         1.0     107.54        0.43    7.0       NaN    62.0
# 1        2         3.0      64.70        0.20    6.0         A    72.0
# 2        1         1.0     155.80        0.70    9.0         B    72.0
# 3        1         1.0      83.90        1.20    8.0       NaN    71.5
# 4        0         1.0     269.70        0.30    7.0       NaN    71.0

# %%
algae.season.value_counts()
algae.season.value_counts().plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print (algae.info())
algae.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
# season             200 non-null object
# river_size         200 non-null object
# fluid_velocity     200 non-null object
# pH                 199 non-null float64
# Oxygen             198 non-null float64
# Chloride           190 non-null float64
# Nitrates           198 non-null float64
# Ammonium           198 non-null float64
# Orthophosphate     198 non-null float64
# Phosphate          198 non-null float64
# Chlorophyll        188 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 17.3+ KB
# None
#                pH      Oxygen    Chloride    Nitrates    Ammonium  \
# count  199.000000  198.000000  190.000000  198.000000  198.000000
# mean     8.011759    9.117778   43.636842    3.282828  154.447475
# std      0.598302    2.391253   46.830993    3.776458  180.011207
# min      5.600000    1.500000    0.220000    0.050000    5.000000
# 25%      7.700000    7.725000   10.985000    1.297500   35.625000
# 50%      8.060000    9.800000   32.730000    2.675000   99.665000
# 75%      8.400000   10.800000   57.825000    4.447500  203.730000
# max      9.700000   13.400000  391.500000   45.650000  931.830000
#
#        Orthophosphate   Phosphate  Chlorophyll
# count      198.000000  198.000000   188.000000
# mean        83.325909  111.550808    13.541011
# std        116.783165  102.214088    20.448323
# min          1.000000    0.900000     0.000000
# 25%         16.000000   19.395000     2.000000
# 50%         41.400000   84.500000     5.200000
# 75%        102.247500  182.160000    18.300000
# max        771.600000  558.750000   110.460000

# %%
algae.isnull().sum()
# Out:
# season              0
# river_size          0
# fluid_velocity      0
# pH                  1
# Oxygen              2
# Chloride           10
# Nitrates            2
# Ammonium            2
# Orthophosphate      2
# Phosphate           2
# Chlorophyll        12
# dtype: int64
