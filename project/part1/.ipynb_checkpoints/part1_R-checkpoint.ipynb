# %% [markdown]
# ## Import packages

# %%
install.packages("arules")
library(arules)
# Out:
# Installing package into ‘/home/martinho/R/x86_64-pc-linux-gnu-library/3.3’
# (as ‘lib’ is unspecified)
# Loading required package: Matrix
#
# Attaching package: ‘arules’
#
# The following objects are masked from ‘package:base’:
#
#     abbreviate, write

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/home/martinho/R/x86_64-pc-linux-gnu-library/3.3’
# (as ‘lib’ is unspecified)

# %%
discretize_all = function(table_d, type, n){
    for (i in 1:ncol(table_d)) {
        if (is.numeric(table_d[[i]])) {
            table_d[[i]]  =  discretize(table_d[[i]],  method  =  type,  categories  =  n, ordered=TRUE)
        }
    }
    print(summary(table_d))
    return(table_d);
}

# %% [markdown]
# #### Change directory

# %%
setwd("~/Documents/IST/SAD/project")

# %% [markdown]
# ## 1. - crabs.csv
# ### a.

# %%
library(readr)
crabs <-read_csv("data/crabs.csv")
crabs$sp <- NULL
class(crabs)
# Out:
# Parsed with column specification:
# cols(
#   sp = col_character(),
#   sex = col_character(),
#   index = col_integer(),
#   FL = col_double(),
#   RW = col_double(),
#   CL = col_double(),
#   CW = col_double(),
#   BD = col_double()
# )
# [1] "tbl_df"     "tbl"        "data.frame"

# %%
library(dplyr)
crabs = mutate_if(crabs, is.character, as.factor)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:arules’:
#
#     intersect, recode, setdiff, setequal, union
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
head(crabs_int_2,n=2)
# Out:
# Error in head(crabs_int_2, n = 2): object 'crabs_int_2' not found
# Traceback:
#
# 1. head(crabs_int_2, n = 2)

# %%
is <- apriori(crabs_int_2, parameter = list(support = 0.2,confidence=0.97, target="rules"))
isdf <- as(is,"data.frame")
mean(isdf[["confidence"]])
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#        0.97    0.1    1 none FALSE            TRUE       5     0.2      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 40
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [14 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [336 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# [1] 0.9927366

# %%
crabs_int_2 = discretize_all(crabs, "interval",2)
min_sup = 87/200
min_x_2 = min_sup
i=0 

sup_2 <- vector()
rules_2 <- vector()
confidence_2 <- vector()
while (min_sup <= 1){
    sup_2[i] <- min_sup
    i=i+1
    min_sup = min_sup + 0.001
}
i=1
for (value in sup_2){
    is <- apriori(crabs_int_2, parameter = list(support = value, target="rules"))
    is_o <- as(is,"data.frame")
    rules_2[i]<-length(is)
    #ruledf = data.frame(lhs = labels(lhs(is_o))$elements,rhs = labels(rhs(is_o))$elements, is_o@quality)
    total_con=0
    if (is.na(mean(is_o[["confidence"]]))){
        confidence_2[i] <- 0
    } else {
        confidence_2[i] <- mean(is_o[["confidence"]])
        
    }
    
    i=i+1
}
# Out:
#  sex             index               FL                RW
#  F:100   [ 1.0,25.5):100   [ 7.2,15.2): 93   [ 6.5,13.3):113
#  M:100   [25.5,50.0]:100   [15.2,23.1]:107   [13.3,20.2]: 87
#            CL                CW                BD
#  [14.7,31.2): 86   [17.1,35.9): 93   [ 6.1,13.9): 98
#  [31.2,47.6]:114   [35.9,54.6]:107   [13.9,21.6]:102
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.436      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 87
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [52 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.437      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 87
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [52 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.438      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 87
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [52 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.439      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 87
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [52 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.44      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 88
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [52 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.441      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 88
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [49 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.442      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 88
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [49 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.443      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 88
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [49 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.444      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 88
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [49 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.445      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 89
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [49 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.446      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 89
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [36 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.447      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 89
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [36 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.448      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 89
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [36 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.449      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 89
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [36 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.45      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 90
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [36 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.451      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 90
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.452      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 90
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.453      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 90
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.454      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 90
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.455      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 91
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.456      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 91
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.457      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 91
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.458      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 91
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.459      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 91
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.46      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 92
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.461      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 92
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.462      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 92
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.463      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 92
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.464      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 92
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.465      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 93
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [12 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [35 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.466      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 93
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [28 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.467      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 93
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [28 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.468      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 93
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [28 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.469      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 93
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [28 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.47      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 94
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [28 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.471      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 94
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [21 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.472      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 94
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [21 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.473      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 94
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [21 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.474      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 94
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [21 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.475      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 95
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [21 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.476      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 95
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.477      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 95
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.478      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 95
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.479      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 95
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.48      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 96
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.481      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 96
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.482      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 96
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.483      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 96
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.484      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 96
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [16 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.485      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 97
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [11 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.486      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 97
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [11 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.487      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 97
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [11 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.488      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 97
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [11 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.489      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 97
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.00s].
# writing ... [11 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.49      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 98
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [6 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.491      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 98
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [6 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.492      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 98
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [6 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.493      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 98
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [6 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.494      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 98
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [6 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.495      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 99
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.496      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 99
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.497      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 99
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.498      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 99
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.499      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 99
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5     0.5      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 100
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.501      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 100
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [5 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.502      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 100
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [5 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [4 rule(s)] done [0.00s].
# ...
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.981      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.982      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.983      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.984      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.985      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.986      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.987      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.988      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.989      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.99      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.991      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.992      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.993      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.994      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.995      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.996      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.997      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.998      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.999      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[14 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Warning message in mean.default(is_o[["confidence"]]):
# “argument is not numeric or logical: returning NA”

# %%
length(sup_2)
length(rules_2)
length(confidence_2)
# Out:
# [1] 564
# [1] 564
# [1] 564
#   [1] 0.9408373 0.9408373 0.9408373 0.9408373 0.9408373 0.9414920 0.9414920
#   [8] 0.9414920 0.9414920 0.9414920 0.9428283 0.9428283 0.9428283 0.9428283
#  [15] 0.9428283 0.9435272 0.9435272 0.9435272 0.9435272 0.9435272 0.9435272
#  [22] 0.9435272 0.9435272 0.9435272 0.9435272 0.9435272 0.9435272 0.9435272
#  [29] 0.9435272 0.9435272 0.9375026 0.9375026 0.9375026 0.9375026 0.9375026
#  [36] 0.9423096 0.9423096 0.9423096 0.9423096 0.9423096 0.9451146 0.9451146
#  [43] 0.9451146 0.9451146 0.9451146 0.9451146 0.9451146 0.9451146 0.9451146
#  [50] 0.9410746 0.9410746 0.9410746 0.9410746 0.9410746 0.9436415 0.9436415
#  [57] 0.9436415 0.9436415 0.9436415 0.9557100 0.9557100 0.9557100 0.9557100
#  [64] 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100
#  [71] 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100
#  [78] 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100 0.9557100
#  [85] 0.9557100 0.9692982 0.9692982 0.9692982 0.9692982 0.9692982 0.9692982
#  [92] 0.9692982 0.9692982 0.9692982 0.9692982 0.9692982 0.9692982 0.9692982
#  [99] 0.9692982 0.9692982 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [106] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [113] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [120] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [127] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [134] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [141] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [148] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [155] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [162] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [169] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [176] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [183] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [190] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [197] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [204] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [211] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [218] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [225] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [232] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [239] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [246] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [253] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [260] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [267] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [274] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [281] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [288] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [295] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [302] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [309] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [316] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [323] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [330] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [337] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [344] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [351] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [358] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [365] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [372] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [379] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [386] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [393] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [400] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [407] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [414] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [421] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [428] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [435] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [442] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [449] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [456] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [463] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [470] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [477] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [484] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [491] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [498] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [505] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [512] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [519] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [526] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [533] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [540] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [547] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [554] 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000 0.0000000
# [561] 0.0000000 0.0000000 0.0000000 0.0000000

# %%
#plot(sup_2,rules_2,type="l",xlim=c(min_x_2,0.55))
plot(sup_2,confidence_2,type="l",xlim=c(min_x_2,0.55))
# Out:
# plot without title

# %%
crabs_int_3 = discretize_all(crabs, "interval",3)
min_sup = 31/200
min_x_3 = min_sup
i=0 
sup_3 <- vector()
rules_3 <- vector()
while (min_sup <= 1){
    sup_3[i] <- min_sup
    i=i+1
    min_sup = min_sup + 0.001
}
i=1
for (value in sup_3){
    is <- apriori(crabs_int_3, parameter = list(support = value, target="rules"))
    rules_3[i]<-length(is)
    i=i+1
}
# Out:
#  sex             index              FL                RW                CL
#  F:100   [ 1.0,17.3):68   [ 7.2,12.5): 37   [ 6.5,11.1): 53   [14.7,25.7): 38
#  M:100   [17.3,33.7):64   [12.5,17.8):106   [11.1,15.6):116   [25.7,36.6):106
#          [33.7,50.0]:68   [17.8,23.1]: 57   [15.6,20.2]: 31   [36.6,47.6]: 56
#            CW                BD
#  [17.1,29.6): 40   [ 6.1,11.3): 46
#  [29.6,42.1):111   [11.3,16.4):102
#  [42.1,54.6]: 49   [16.4,21.6]: 52
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.156      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 31
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [474 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.157      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 31
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [474 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.158      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 31
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [474 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.159      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 31
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [474 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.16      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 32
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [474 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.161      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 32
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [413 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.162      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 32
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [413 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.163      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 32
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [413 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.164      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 32
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [413 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.165      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 33
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [413 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.166      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 33
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [408 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.167      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 33
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [408 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.168      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 33
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [408 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.169      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 33
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [408 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.17      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 34
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [408 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.171      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 34
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [368 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.172      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 34
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [368 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.173      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 34
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [368 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.174      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 34
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [368 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.175      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 35
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [368 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.176      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 35
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [341 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.177      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 35
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [341 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.178      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 35
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [341 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.179      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 35
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [341 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.18      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 36
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.181      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 36
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.182      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 36
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.183      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 36
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.184      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 36
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [19 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.185      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 37
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [18 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [326 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.186      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 37
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [18 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [326 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.187      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 37
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [18 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [326 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.188      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 37
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [18 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [326 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.189      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 37
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [18 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [326 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.19      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 38
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.191      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 38
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.192      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 38
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.193      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 38
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.194      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 38
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.195      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 39
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.196      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 39
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.197      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 39
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.198      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 39
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.199      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 39
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [17 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [321 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5     0.2      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 40
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [310 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.201      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 40
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [310 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.202      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 40
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [310 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.203      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 40
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [310 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.204      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 40
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [310 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.205      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 41
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [303 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.206      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 41
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [303 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.207      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 41
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [303 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.208      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 41
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [303 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.209      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 41
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [303 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.21      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 42
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [285 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.211      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 42
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [285 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.212      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 42
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [285 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.213      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 42
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [285 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.214      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 42
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [285 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.215      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 43
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [256 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.216      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 43
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [256 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.217      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 43
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [256 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.218      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 43
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [256 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.219      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 43
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [256 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.22      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 44
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 done [0.00s].
# writing ... [217 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.221      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 44
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [16 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 done [0.00s].
# writing ... [217 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
# ...
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.978      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.979      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.98      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.981      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.982      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.983      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.984      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.985      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.986      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.987      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.988      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.989      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.99      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.991      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.992      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.993      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.994      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.995      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.996      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.997      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.998      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.999      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[20 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].

# %%
length(sup_3)
length(rules_3)
# Out:
# [1] 844
# [1] 844

# %%
plot(sup_3,rules_3,type="l",xlim=c(min_x_3,0.5))
# Out:
# plot without title

# %%
crabs_int_4 = discretize_all(crabs, "interval",4)
min_sup = 12/200
min_x_4 = min_sup
i=0 
sup_4 <- vector()
rules_4 <- vector()
while (min_sup <= 1){
    sup_4[i] <- min_sup
    i=i+1
    min_sup = min_sup + 0.001
}
i=1
for (value in sup_4){
    is <- apriori(crabs_int_4, parameter = list(support = value, target="rules"))
    rules_4[i]<-length(is)
    i=i+1
}
# Out:
#  sex             index              FL                 RW               CL
#  F:100   [ 1.0,13.2):52   [ 7.2,11.2):22   [ 6.50, 9.93):28   [14.7,22.9):23
#  M:100   [13.2,25.5):48   [11.2,15.2):71   [ 9.93,13.35):85   [22.9,31.2):63
#          [25.5,37.8):48   [15.2,19.1):73   [13.35,16.77):75   [31.2,39.4):79
#          [37.8,50.0]:52   [19.1,23.1]:34   [16.77,20.20]:12   [39.4,47.6]:35
#            CW                 BD
#  [17.1,26.5):23   [ 6.10, 9.97):25
#  [26.5,35.9):70   [ 9.97,13.85):73
#  [35.9,45.2):81   [13.85,17.73):69
#  [45.2,54.6]:26   [17.73,21.60]:33
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.061      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1486 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.062      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1486 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.063      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1486 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.064      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1486 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.065      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1486 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.066      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1352 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.067      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1352 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.068      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1352 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.069      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1352 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.07      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1220 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.071      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1220 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.072      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1220 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.073      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1220 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.074      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1220 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.075      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1073 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.076      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1073 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.077      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1073 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.078      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1073 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.079      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1073 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.08      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1012 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.081      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1012 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.082      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1012 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.083      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1012 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.084      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [1012 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.085      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [934 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.086      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [934 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.087      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [934 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.088      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [934 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.089      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [934 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.09      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [888 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.091      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [888 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.092      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [888 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.093      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [888 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.094      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [888 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.095      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 19
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [873 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.096      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 19
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [873 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.097      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 19
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [873 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.098      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 19
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [873 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.099      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 19
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [873 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5     0.1      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 20
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [711 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.101      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 20
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [711 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.102      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 20
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [711 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.103      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 20
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [711 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.104      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 20
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [711 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.105      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 21
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [663 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.106      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 21
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [663 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.107      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 21
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [663 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.108      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 21
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [663 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.109      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 21
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [25 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [663 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.11      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 22
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [24 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [580 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.111      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 22
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [24 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [580 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.112      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 22
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [24 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [580 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.113      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 22
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [24 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [580 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.114      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 22
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [24 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [580 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.115      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 23
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [560 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.116      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 23
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [560 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.117      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 23
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [560 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.118      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 23
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [560 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.119      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 23
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [560 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.12      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 24
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [511 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.121      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 24
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [511 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.122      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 24
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [511 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.123      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 24
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [511 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.124      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 24
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [22 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [511 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.125      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 25
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [21 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [458 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.126      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 25
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [21 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [458 rule(s)] done [0.00s].
# ...
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.978      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.979      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.98      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.981      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.982      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.983      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.984      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.985      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.986      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.987      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.988      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.989      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5    0.99      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.991      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.992      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.993      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.994      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.995      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.996      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.997      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.998      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5   0.999      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[26 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].

# %%
length(sup_4)
length(rules_4)
# Out:
# [1] 939
# [1] 939

# %%
plot(sup_4,rules_4,type="l",xlim=c(min_x_4,0.4))
# Out:
# plot without title

# %%
crabs_int_5 = discretize_all(crabs, "interval",5)
min_sup = 6/200
min_x_5 = min_sup
i=0 
sup_5 <- vector()
rules_5 <- vector()
while (min_sup <= 1){
    sup_5[i] <- min_sup
    i=i+1
    min_sup = min_sup + 0.001
}
i=1
for (value in sup_5){
    is <- apriori(crabs_int_5, parameter = list(support = value, conf = 0.9, target="rules"))
    rules_5[i]<-length(is)
    i=i+1
}
# Out:
#  sex             index              FL                 RW               CL
#  F:100   [ 1.0,10.8):40   [ 7.2,10.4):15   [ 6.50, 9.24):18   [14.7,21.3):15
#  M:100   [10.8,20.6):40   [10.4,13.6):45   [ 9.24,11.98):62   [21.3,27.9):43
#          [20.6,30.4):40   [13.6,16.7):66   [11.98,14.72):79   [27.9,34.4):63
#          [30.4,40.2):40   [16.7,19.9):51   [14.72,17.46):35   [34.4,41.0):57
#          [40.2,50.0]:40   [19.9,23.1]:23   [17.46,20.20]: 6   [41.0,47.6]:22
#            CW               BD
#  [17.1,24.6):17   [ 6.1, 9.2):18
#  [24.6,32.1):45   [ 9.2,12.3):46
#  [32.1,39.6):64   [12.3,15.4):66
#  [39.6,47.1):54   [15.4,18.5):50
#  [47.1,54.6]:20   [18.5,21.6]:20
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.031      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 6
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.032      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 6
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.033      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 6
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.034      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 6
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.035      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 7
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1499 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.036      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 7
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1499 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.037      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 7
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1499 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.038      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 7
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1499 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.039      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 7
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1499 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.04      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 8
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1426 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.041      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 8
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1426 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.042      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 8
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1426 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.043      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 8
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1426 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.044      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 8
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1426 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.045      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 9
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1099 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.046      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 9
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1099 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.047      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 9
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1099 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.048      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 9
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1099 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.049      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 9
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [1099 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.05      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 10
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [933 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.051      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 10
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [933 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.052      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 10
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [933 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.053      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 10
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [933 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.054      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 10
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [933 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.055      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 11
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [805 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.056      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 11
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [805 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.057      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 11
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [805 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.058      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 11
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [805 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.059      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 11
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [805 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.06      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.061      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.062      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.063      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.064      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 12
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.00s].
# writing ... [729 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.065      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [615 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.066      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [615 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.067      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [615 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.068      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [615 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.069      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 13
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [615 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.07      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [478 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.071      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [478 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.072      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [478 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.073      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [478 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.074      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [31 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [478 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.075      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [376 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.076      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [376 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.077      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [376 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.078      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [376 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.079      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 15
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [376 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.08      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.081      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.082      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.083      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.084      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 16
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [29 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [333 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.085      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [28 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [294 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.086      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [28 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [294 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.087      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [28 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [294 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.088      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [28 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [294 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.089      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 17
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [28 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [294 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.09      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [26 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [249 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.091      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [26 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [249 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.092      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [26 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [249 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.093      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [26 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [249 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.094      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 18
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [26 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [249 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.095      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 19
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [26 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [219 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.096      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 19
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [26 item(s)] done [0.00s].
# ...
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.978      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.979      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 195
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.98      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.981      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.982      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.983      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.984      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 196
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.985      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.986      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.987      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.988      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.989      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 197
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5    0.99      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.991      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.992      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.993      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.994      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 198
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.995      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.996      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.997      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.998      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.9    0.1    1 none FALSE            TRUE       5   0.999      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 199
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[32 item(s), 200 transaction(s)] done [0.00s].
# sorting and recoding items ... [0 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 done [0.00s].
# writing ... [0 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].

# %%
length(sup_5)
length(rules_5)
# Out:
# [1] 969
# [1] 969

# %%
plot(sup_5,rules_5,type="l",xlim=c(min_x_5,0.35))
# Out:
# plot without title

# %% [markdown]
# ### b.

# %%
adult = read.transactions("data/adult.csv",format="basket", sep=",")

# %%
adult_rules <- apriori(adult, parameter = list(supp = 0.5, conf = 0.9, target = "rules"))

# %%
inspect(adult_rules)

# %% [markdown]
# ## 2. - vote.csv
# ### a.

# %%
library(readr)
vote <-read_csv("data/vote.csv")

# %% [markdown]
# #### Este comando dá erro e é previsto dar erro, pelo menos é o que a stora diz no doc de apoio. Mas não percebo bem porque é que isso acontece

# %%
rules_vote <-apriori(vote, parameter = list(supp = 0.1, conf = 1, target = "rules")

# %%
library(dplyr)
vote = mutate_if(vote, is.character, as.factor)
head(vote,n=5)

# %%
vote_rules_sup_0_1 <-apriori(vote, parameter = list(supp = 0.1, conf = 0.8,maxlen=100)) 
vote_rules_sup_0_2 <-apriori(vote, parameter = list(supp = 0.2, conf = 0.8,maxlen=100)) 
vote_rules_sup_0_5 <-apriori(vote, parameter = list(supp = 0.5, conf = 0.8,maxlen=100)) 
vote_rules_conf_0_1 <-apriori(vote, parameter = list(supp = 0.1, conf = 0.1,maxlen=100)) 
vote_rules_conf_0_2 <-apriori(vote, parameter = list(supp = 0.2, conf = 0.2,maxlen=100)) 
vote_rules_conf_0_5 <-apriori(vote, parameter = list(supp = 0.5, conf = 0.5,maxlen=100))

# %% [markdown]
# ### b.

# %%
inspect(head(sort(vote_rules_sup_0_1,by="lift",decreasing = FALSE),n=3))

# %%
inspect(head(sort(vote_rules_sup_0_2,by="lift",decreasing = FALSE),n=3))

# %%
inspect(head(sort(vote_rules_sup_0_5,by="lift",decreasing = FALSE),n=3))

# %%
inspect(head(sort(vote_rules_conf_0_1,by="lift",decreasing = FALSE),n=3))

# %%
inspect(head(sort(vote_rules_conf_0_2,by="lift",decreasing = FALSE),n=3))

# %%
inspect(head(sort(vote_rules_conf_0_5,by="lift",decreasing = FALSE),n=3))

# %% [markdown]
# ### c.

# %% [markdown]
# Case não funciona porque convictio = NaN

# %%
case1 = cbind(as(vote_rules_sup_0_1, "data.frame"), conviction=interestMeasure(vote_rules_sup_0_1, "conviction", vote))
case1 = case1[complete.cases(case1), ]
dim(case1)
head(case1,n=3)
n1 = which(case1$conviction >= 1)
length(n1)

# %%
case2 = cbind(as(vote_rules_sup_0_2, "data.frame"), conviction=interestMeasure(vote_rules_sup_0_2, "conviction", vote))
case2 = case2[complete.cases(case2), ]
dim(case2)
head(case2,n=3)
n2 = which(case2$conviction >= 1)
length(n2)

# %%
case3 = cbind(as(vote_rules_sup_0_5, "data.frame"), conviction=interestMeasure(vote_rules_sup_0_5, "conviction", vote))
case3 = case1[complete.cases(case3), ]
dim(case3)
head(case3,n=3)
n3 = which(case3$conviction >= 1)
length(n3)

# %%
case4 = cbind(as(vote_rules_conf_0_1, "data.frame"), conviction=interestMeasure(vote_rules_conf_0_1, "conviction", vote))
case4 = case4[complete.cases(case4), ]
dim(case4)
head(case4,n=3)
n4 = which(case4$conviction >= 1)
length(n4)

# %%
case5 = cbind(as(vote_rules_conf_0_2, "data.frame"), conviction=interestMeasure(vote_rules_conf_0_2, "conviction", vote))
case5 = case5[complete.cases(case5), ]
dim(case5)
head(case5,n=3)
n5 = which(case5$conviction >= 1)
length(n5)

# %%
case6 = cbind(as(vote_rules_conf_0_5, "data.frame"), conviction=interestMeasure(vote_rules_conf_0_5, "conviction", vote))
case6 = case6[complete.cases(case6), ]
dim(case6)
head(case6,n=3)
n6 = which(case6$conviction >= 1)
length(n6)

# %% [markdown]
# ### d.

# %% [markdown]
# Não sei bem o que responder aqui!

# %% [markdown]
# ## 3. - supermarket.csv
# ### a.

# %%
supermarket <-read_csv("data/supermarket.csv")
head(supermarket,n=5)

# %% [markdown]
# #### Aqui tambem é previsto dar erro, mas também não percebo bem porquê :o

# %%
supermaket_rules <-apriori(supermarket, parameter = list(supp =0.9, conf = 1, maxlen=100, target = "rules"))

# %%
supermarket = mutate_if(supermarket, is.character, as.factor)

# %%
supermaket_rules <-apriori(supermarket, parameter = list(supp = 0.9, conf = 1, maxlen=10, target = "rules"))

# %%
write(supermaket_rules[1:10],"",sep="\n ", quote=TRUE)

# %% [markdown]
# ### b.

# %% [markdown]
# ### c.

# %% [markdown]
# ## 4. - glass.csv
# ### a.

# %%
glass <-read_csv("data/glass.csv")
head(glass,n=5)

# %%
glass_d_int = discretize_all(glass, "interval",3)
class(glass_d_int)

# %%
head(glass_d_int,n=5)

# %%
glass_d_fr = discretize_all(glass, "frequency",3)

# %%
head(glass_d_fr,n=5)

# %%
rules <-apriori(supermarket, parameter = list(supp = 0.9, conf = 1, maxlen=10, target = "rules"))
